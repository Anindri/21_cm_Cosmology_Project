# %%
"""
Assumption (Ts=Tk)  [when Lyman-alpha coefficient is very high]

"""

import os
import numpy as np
import matplotlib.pyplot as plt
import glob

d_path=r'G:\CD_data_project'
#output_path=r"‪G:\T_spin"
#output_path = output_path.strip().replace('\u202a', '')

#read data 
def read_data(file):
    f=open(file,'rb')
    n=np.fromfile(f,count=3,dtype='int32')
    d=np.fromfile(f,dtype='float32')
    return d

def exTract(model,solar_mass,parameter):
    
    pattern = os.path.join(d_path, f"*{solar_mass}*{model}*{parameter}.cbin")
    files = sorted(glob.glob(pattern))

    redshifts=[]
    mean_d=[]

    for f in files:        
        #extracting z from path
        fname=os.path.basename(f)
        z_=fname.split("zeta")[0]
        z=float(z_)

        data=read_data(f)
        m=np.mean(data)

        redshifts.append(z)
        mean_d.append(m)

    #sort by making list
    data=list(zip(redshifts,mean_d))
    data.sort()
    redshifts,mean_d=(zip(*data))

    return np.array(redshifts),np.array(mean_d)

# %%
model,solar_mass="fx0.100E+00","Mmin0.100E+10"
#z1,x_alpha=exTract(model,solar_mass,"lyalpha")
z2,T_k=exTract(model,solar_mass,"tk")
Tcmb=2.725*(1+z2)
T_spin=[]
T_spin=T_k

print("For X-ray heating model fx0.1,and halo-mass of $10^{9}$ $M_{\\odot}$ \n")
for z,ts in zip(z2,T_spin):
    print(f"for redshift={z} , Spin Temperature={ts}")
"""
    #save the files
    z_str=f"{z:.3f}"
    print(repr(output_path))
    filename=f"{z:.3f}_{solar_mass}_{model}_tspin.cbin"
    fpath=os.path.join(output_path,filename)

    f=open(fpath,'wb')
    head=np.array([1,2,3],dtype='int32')
    head.tofile(f)
    np.array([ts],dtype='float32').tofile(f)
    f.close()
"""
# Out:
# For X-ray heating model fx0.1,and halo-mass of $10^{9}$ $M_{\odot}$
#
# for redshift=10.11 , Spin Temperature=983.56396484375
# for redshift=10.29 , Spin Temperature=855.8850708007812
# for redshift=10.478 , Spin Temperature=737.7922973632812
# for redshift=10.673 , Spin Temperature=627.543212890625
# for redshift=10.877 , Spin Temperature=530.84765625
# for redshift=11.313 , Spin Temperature=364.4361267089844
# for redshift=11.546 , Spin Temperature=297.33111572265625
# for redshift=11.791 , Spin Temperature=237.7559356689453
# for redshift=12.048 , Spin Temperature=187.19415283203125
# for redshift=12.318 , Spin Temperature=145.6698760986328
# for redshift=12.603 , Spin Temperature=110.77182006835938
# for redshift=12.903 , Spin Temperature=82.71160125732422
# for redshift=13.221 , Spin Temperature=60.47422409057617
# for redshift=13.557 , Spin Temperature=43.287349700927734
# for redshift=13.914 , Spin Temperature=30.61823081970215
# ...

# %%
fig,ax=plt.subplots(figsize=(8,4))

ax.plot(z2,T_spin,linestyle='-',color='red')
ax.set_title(f"Spin Temperature for model fx={model} and minimum halo-mass={solar_mass}")
ax.set_xlabel("z")    
ax.set_ylabel("mean Ts")   
ax.invert_xaxis()
ax.grid(True)
#ax.legend()
plt.show()

# %%
model,solar_mass="fx0.100E+00","Mmin0.100E+11"
#z1,x_alpha=exTract(model,solar_mass,"lyalpha")
z2,T_k=exTract(model,solar_mass,"tk")

T_spin1=[]
T_spin1=T_k

print("For X-ray heating model fx0.1,and halo-mass of $10^{10}$ $M_{\\odot}$ \n")
for z,ts in zip(z2,T_spin1):
    print(f"for redshift={z} , Spin Temperature={ts}")
"""
    #save the files
    z_str=f"{z:.3f}"
    print(repr(output_path))
    filename=f"{z:.3f}_{solar_mass}_{model}_tspin.cbin"
    fpath=os.path.join(output_path,filename)

    f=open(fpath,'wb')
    head=np.array([1,2,3],dtype='int32')
    head.tofile(f)
    np.array([ts],dtype='float32').tofile(f)
    f.close()
"""
# Out:
# For X-ray heating model fx0.1,and halo-mass of $10^{10}$ $M_{\odot}$
#
# for redshift=10.11 , Spin Temperature=256.7223815917969
# for redshift=10.29 , Spin Temperature=209.11300659179688
# for redshift=10.478 , Spin Temperature=168.39154052734375
# for redshift=10.673 , Spin Temperature=133.1475830078125
# for redshift=10.877 , Spin Temperature=104.23063659667969
# for redshift=11.313 , Spin Temperature=60.09732437133789
# for redshift=11.546 , Spin Temperature=44.75235366821289
# for redshift=11.791 , Spin Temperature=32.622318267822266
# for redshift=12.048 , Spin Temperature=23.663698196411133
# for redshift=12.318 , Spin Temperature=17.198413848876953
# for redshift=12.603 , Spin Temperature=12.567501068115234
# for redshift=12.903 , Spin Temperature=9.403053283691406
# for redshift=13.221 , Spin Temperature=7.375259876251221
# for redshift=13.557 , Spin Temperature=6.188851356506348
# for redshift=13.914 , Spin Temperature=5.577258110046387
# ...

# %%
fig,ax=plt.subplots(figsize=(8,4))

ax.plot(z2,T_spin1,linestyle='-',color='red')
ax.set_title(f"Spin Temperature for model fx={model} and minimum halo-mass={solar_mass}")
ax.set_xlabel("z")    
ax.set_ylabel("mean Ts")   
ax.invert_xaxis()
ax.grid(True)
#ax.legend()
plt.show()

# %%
model,solar_mass="fx0.100E+04","Mmin0.100E+10"
#z1,x_alpha=exTract(model,solar_mass,"lyalpha")
z2,T_k=exTract(model,solar_mass,"tk")
T_spin2=[]
T_spin2=T_k

print("For X-ray heating model fx1000,and halo-mass of $10^{9}$ $M_{\\odot}$ \n")

for z,ts in zip(z2,T_spin2):
    print("for redshift=",z,"  Spin Temperature=",ts)
"""
    #save the files
    z_str=f"{z:.3f}"
    print(repr(output_path))
    filename=f"{z:.3f}_{solar_mass}_{model}_tspin.cbin"
    fpath=os.path.join(output_path,filename)

    f=open(fpath,'wb')
    head=np.array([1,2,3],dtype='int32')
    head.tofile(f)
    np.array([ts],dtype='float32').tofile(f)
    f.close()
"""
# Out:
# For X-ray heating model fx1000,and halo-mass of $10^{9}$ $M_{\odot}$
#
# for redshift= 10.11   Spin Temperature= 14263.966
# for redshift= 10.29   Spin Temperature= 13083.93
# for redshift= 10.478   Spin Temperature= 11676.296
# for redshift= 10.673   Spin Temperature= 10081.634
# for redshift= 10.877   Spin Temperature= 8466.938
# for redshift= 11.313   Spin Temperature= 5484.7
# for redshift= 11.546   Spin Temperature= 4266.103
# for redshift= 11.791   Spin Temperature= 3241.7021
# for redshift= 12.048   Spin Temperature= 2407.8457
# for redshift= 12.318   Spin Temperature= 1748.7759
# for redshift= 12.603   Spin Temperature= 1235.2068
# for redshift= 12.903   Spin Temperature= 852.38275
# for redshift= 13.221   Spin Temperature= 572.71826
# for redshift= 13.557   Spin Temperature= 373.58774
# for redshift= 13.914   Spin Temperature= 234.75006
# for redshift= 14.294   Spin Temperature= 144.35849
# for redshift= 14.699   Spin Temperature= 86.834915
# ...

# %%
fig,ax=plt.subplots(figsize=(8,4))

ax.plot(z2,T_spin2,linestyle='-',color='red')
ax.set_title(f"Spin Temperature for model fx={model} and minimum halo-mass={solar_mass}")
ax.set_xlabel("z")    
ax.set_ylabel("mean Ts")   
ax.invert_xaxis()
ax.grid(True)
plt.show()

# %%
model,solar_mass="fx0.100E+04","Mmin0.100E+11"
#z1,x_alpha=exTract(model,solar_mass,"lyalpha")
z2,T_k=exTract(model,solar_mass,"tk")
T_spin3=[]
T_spin3=T_k

print("For X-ray heating model fx1000,and halo-mass of $10^{10}$ $M_{\\odot}$ \n")
for z,ts in zip(z2,T_spin3):
    print("for redshift=",z,"  Spin Temperature=",ts)
"""    
    #save the files
    z_str=f"{z:.3f}"
    print(repr(output_path))
    filename=f"{z:.3f}_{solar_mass}_{model}_tspin.cbin"
    fpath=os.path.join(output_path,filename)

    f=open(fpath,'wb')
    head=np.array([1,2,3],dtype='int32')
    head.tofile(f)
    np.array([ts],dtype='float32').tofile(f)
    f.close()
"""
# Out:
# For X-ray heating model fx1000,and halo-mass of $10^{10}$ $M_{\odot}$
#
# for redshift= 10.11   Spin Temperature= 4536.4897
# for redshift= 10.29   Spin Temperature= 3543.2761
# for redshift= 10.478   Spin Temperature= 2716.7603
# for redshift= 10.673   Spin Temperature= 2039.2122
# for redshift= 10.877   Spin Temperature= 1504.1727
# for redshift= 11.313   Spin Temperature= 761.5432
# for redshift= 11.546   Spin Temperature= 526.10126
# for redshift= 11.791   Spin Temperature= 354.54218
# for redshift= 12.048   Spin Temperature= 232.87976
# for redshift= 12.318   Spin Temperature= 149.24478
# for redshift= 12.603   Spin Temperature= 93.093506
# for redshift= 12.903   Spin Temperature= 56.733162
# for redshift= 13.221   Spin Temperature= 34.40873
# for redshift= 13.557   Spin Temperature= 21.186562
# for redshift= 13.914   Spin Temperature= 13.144557
# for redshift= 14.294   Spin Temperature= 8.902535
# for redshift= 14.699   Spin Temperature= 6.85129
# ...

# %%
fig,ax=plt.subplots(figsize=(8,4))

ax.plot(z2,T_spin3,linestyle='-',color='red')
ax.set_title(f"Spin Temperature for model fx={model} and minimum halo-mass={solar_mass}")
ax.set_xlabel("z")    
ax.set_ylabel("mean Ts")   
ax.invert_xaxis()
ax.grid(True)
plt.show()

# %%
model,solar_mass="fx0.464E+02","Mmin0.100E+10"
#z1,x_alpha=exTract(model,solar_mass,"lyalpha")
z2,T_k=exTract(model,solar_mass,"tk")
T_spin4=[]
T_spin4=T_k

print("For X-ray heating model fx46.4,and halo-mass of $10^{9}$ $M_{\\odot}$ \n")
for z,ts in zip(z2,T_spin4):
    print("for redshift=",z,"  Spin Temperature=",ts)
"""
    #save the files
    z_str=f"{z:.3f}"
    print(repr(output_path))
    filename=f"{z:.3f}_{solar_mass}_{model}_tspin.cbin"
    fpath=os.path.join(output_path,filename)

    f=open(fpath,'wb')
    head=np.array([1,2,3],dtype='int32')
    head.tofile(f)
    np.array([ts],dtype='float32').tofile(f)
    f.close()
"""
# Out:
# For X-ray heating model fx46.4,and halo-mass of $10^{9}$ $M_{\odot}$
#
# for redshift= 10.11   Spin Temperature= 2212.5588
# for redshift= 10.29   Spin Temperature= 1891.436
# for redshift= 10.478   Spin Temperature= 1602.8649
# for redshift= 10.673   Spin Temperature= 1332.3427
# for redshift= 10.877   Spin Temperature= 1101.5359
# for redshift= 11.313   Spin Temperature= 708.2599
# for redshift= 11.546   Spin Temperature= 565.8021
# for redshift= 11.791   Spin Temperature= 437.90622
# for redshift= 12.048   Spin Temperature= 336.25748
# for redshift= 12.318   Spin Temperature= 252.94878
# for redshift= 12.603   Spin Temperature= 182.77165
# for redshift= 12.903   Spin Temperature= 131.82146
# for redshift= 13.221   Spin Temperature= 93.87699
# for redshift= 13.557   Spin Temperature= 65.18694
# for redshift= 13.914   Spin Temperature= 43.196964
# for redshift= 14.294   Spin Temperature= 28.994467
# for redshift= 14.699   Spin Temperature= 19.96
# ...

# %%
fig,ax=plt.subplots(figsize=(8,4))

ax.plot(z2,T_spin4,linestyle='-',color='red')
ax.set_title(f"Spin Temperature for model fx={model} and minimum halo-mass={solar_mass}")
ax.set_xlabel("z")    
ax.set_ylabel("mean Ts")   
ax.invert_xaxis()
ax.grid(True)
plt.show()

# %%
model,solar_mass="fx0.464E+02","Mmin0.100E+11"
#z1,x_alpha=exTract(model,solar_mass,"lyalpha")
z2,T_k=exTract(model,solar_mass,"tk")
T_spin5=[]
T_spin5=T_k

print("For X-ray heating model fx46.4,and halo-mass of $10^{10}$ $M_{\\odot}$ \n")

for z,ts in zip(z2,T_spin5):
    print("for redshift=",z,"  Spin Temperature=",ts)
"""
    #save the files
    z_str=f"{z:.3f}"
    print(repr(output_path))
    filename=f"{z:.3f}_{solar_mass}_{model}_tspin.cbin"
    fpath=os.path.join(output_path,filename)

    f=open(fpath,'wb')
    head=np.array([1,2,3],dtype='int32')
    head.tofile(f)
    np.array([ts],dtype='float32').tofile(f)
    f.close()
"""
# Out:
# For X-ray heating model fx46.4,and halo-mass of $10^{10}$ $M_{\odot}$
#
# for redshift= 10.11   Spin Temperature= 599.2851
# for redshift= 10.29   Spin Temperature= 482.27762
# for redshift= 10.478   Spin Temperature= 384.3254
# for redshift= 10.673   Spin Temperature= 298.67078
# for redshift= 10.877   Spin Temperature= 230.27344
# for redshift= 11.313   Spin Temperature= 125.51404
# for redshift= 11.546   Spin Temperature= 92.17434
# for redshift= 11.791   Spin Temperature= 64.92514
# for redshift= 12.048   Spin Temperature= 45.48061
# for redshift= 12.318   Spin Temperature= 31.094625
# for redshift= 12.603   Spin Temperature= 20.63195
# for redshift= 12.903   Spin Temperature= 14.11045
# for redshift= 13.221   Spin Temperature= 10.077452
# for redshift= 13.557   Spin Temperature= 7.7340283
# for redshift= 13.914   Spin Temperature= 6.2996244
# for redshift= 14.294   Spin Temperature= 5.6794434
# for redshift= 14.699   Spin Temperature= 5.524789
# ...

# %%
fig,ax=plt.subplots(figsize=(8,4))

ax.plot(z2,T_spin5,linestyle='-',color='red')
ax.set_title(f"Spin Temperature for model fx={model} and minimum halo-mass={solar_mass}")
ax.set_xlabel("z")    
ax.set_ylabel("mean Ts")   
ax.invert_xaxis()
ax.grid(True)
plt.show()

# %%
#varying fx=0.1,1000,46.4  fixed min halo-mass=10^9

Ts_file=open()

fig,ax=plt.subplots(figsize=(10,6))

ax.plot(z2,T_spin,linestyle='-',color='blue',label='fx=0.1')
ax.plot(z2,T_spin2,linestyle='-',color='red',label='fx=1000')
ax.plot(z2,T_spin4,linestyle='-',color='green',label='fx=46.4')
ax.set_title("Spin Temperature Comparisons at fixed minimum Halo-mass $10^{9}$ $M_{\\odot}$")
ax.set_xlabel("<--- z")    
ax.set_ylabel("$T_{spin}$ --->")   
ax.invert_xaxis()
ax.grid(True)
ax.legend()
plt.show()

# %%
#varying fx=0.1,1000,46.4  fixed min halo-mass=10^10

fig,ax=plt.subplots(figsize=(10,6))

ax.plot(z2,T_spin1,linestyle='-',color='blue',label='fx=0.1')
ax.plot(z2,T_spin3,linestyle='-',color='red',label='fx=1000')
ax.plot(z2,T_spin5,linestyle='-',color='green',label='fx=46.4')
ax.set_title("Spin Temperature Comparisons at fixed minimum Halo-mass $10^{10}$ $M_{\\odot}$")
ax.set_xlabel("<--- z")    
ax.set_ylabel("$T_{spin}$ --->")   
ax.invert_xaxis()
ax.grid(True)
ax.legend()
plt.show()

# %%
#varying min halo-mass=10^9,10^10 and fixed fx=0.1

fig,ax=plt.subplots(figsize=(10,6))

ax.plot(z2,T_spin,linestyle='-',color='blue',label='$10^{9}$ $M_{\\odot}$')
ax.plot(z2,T_spin1,linestyle='-',color='red',label='$10^{10}$ $M_{\\odot}$')

ax.set_title("Spin Temperature Comparisons at fixed X-ray heating model fx=0.1 ")
ax.set_xlabel("<--- z")    
ax.set_ylabel("$T_{spin}$ --->")   
ax.invert_xaxis()
ax.grid(True)
ax.legend()
plt.show()

# %%
#varying min halo-mass=10^9,10^10 and fixed fx=1000 

fig,ax=plt.subplots(figsize=(10,6))

ax.plot(z2,T_spin2,linestyle='-',color='blue',label='$10^{9}$ $M_{\\odot}$')
ax.plot(z2,T_spin3,linestyle='-',color='red',label='$10^{10}$ $M_{\\odot}$')

ax.set_title("Spin Temperature Comparisons at fixed X-ray heating model fx=1000 ")
ax.set_xlabel("<--- z")    
ax.set_ylabel("$T_{spin}$ --->")   
ax.invert_xaxis()
ax.grid(True)
ax.legend()
plt.show()

# %%
#varying min halo-mass=10^9,10^10 and fixed fx=46.4

fig,ax=plt.subplots(figsize=(10,6))

ax.plot(z2,T_spin4,linestyle='-',color='blue',label='$10^{9}$ $M_{\\odot}$')
ax.plot(z2,T_spin5,linestyle='-',color='red',label='$10^{10}$ $M_{\\odot}$')

ax.set_title("Spin Temperature Comparisons at fixed X-ray heating model fx=46.4 ")
ax.set_xlabel("<--- z")    
ax.set_ylabel("$T_{spin}$ --->")   
ax.invert_xaxis()
ax.grid(True)
ax.legend()
plt.show()

# %%
d_path0=r'G:\T_spin'
#output_path=r"‪G:\T_spin"
#output_path = output_path.strip().replace('\u202a', '')
#10.110_Mmin0.100E+10_fx0.100E+00_tspin.cbin

def exTract0(model,solar_mass):
    
    pattern0 = os.path.join(d_path0, f"*{solar_mass}*{model}*tspin.cbin")
    files0 = sorted(glob.glob(pattern0))

    redshifts0=[]
    Ts0=[]

    for f in files0:        
        #extracting z from path
        fname=os.path.basename(f)
        z_=fname.split("_Mmin")[0]
        z=float(z_)

        data=read_data(f)
        m=np.mean(data)

        redshifts0.append(z)
        Ts0.append(m)

    #sort by making list
    data0=list(zip(redshifts0,Ts0))
    data0.sort()
    redshifts0,Ts0=(zip(*data0))

    return np.array(redshifts0),np.array(Ts0)

# %%
model,solar_mass="fx0.100E+00","Mmin0.100E+10"
z0,Ts=exTract0(model,solar_mass)

model,solar_mass="fx0.100E+00","Mmin0.100E+11"
z0,Ts1=exTract0(model,solar_mass)

model,solar_mass="fx0.100E+04","Mmin0.100E+10"
z0,Ts2=exTract0(model,solar_mass)

model,solar_mass="fx0.100E+04","Mmin0.100E+11"
z0,Ts3=exTract0(model,solar_mass)

model,solar_mass="fx0.464E+02","Mmin0.100E+10"
z0,Ts4=exTract0(model,solar_mass)

model,solar_mass="fx0.464E+02","Mmin0.100E+11"
z0,Ts5=exTract0(model,solar_mass)

# %%
#varying fx=0.1,1000,46.4  fixed min halo-mass=10^9

fig,ax=plt.subplots(figsize=(12,8))

ax.plot(z2,Ts,linestyle='--',color='steelblue',label='fx=0.1 ($T_s$ \u2260 $T_k$)')
ax.plot(z2,Ts2,linestyle='--',color='darkred',label='fx=1000 ($T_s$ \u2260 $T_k$)')
ax.plot(z2,Ts4,linestyle='--',color='darkolivegreen',label='fx=46.4 ($T_s$ \u2260 $T_k$)')
ax.plot(z2,T_spin,linestyle='-',color='blue',label='fx=0.1')
ax.plot(z2,T_spin2,linestyle='-',color='red',label='fx=1000')
ax.plot(z2,T_spin4,linestyle='-',color='green',label='fx=46.4')
ax.set_title("Spin Temperature Comparisons at fixed minimum Halo-mass $10^{9}$ $M_{\\odot}$")
ax.set_xlabel("<--- z")    
ax.set_ylabel("$T_{spin}$ [K]--->")
#ax.set_ylim(0,4000)
ax.invert_xaxis()
ax.grid(True)
ax.legend()
plt.show()

# %%
"""
For varying fx=0.1,1000,46.4 at fixed halo mass 10^9:
I have observed the divergence is most for fx1000. 
Divergence at z=around 15 , for 0.1fx
Divergence at z=around 11 , for 46.4fx
Divergence at z=around 15 , for 1000fx
Spin temperature couples best with Kinetic Temperature for the model fx46.4
"""

# %%
#varying fx=0.1,1000,46.4  fixed min halo-mass=10^9

fig,ax=plt.subplots(figsize=(12,8))

ax.plot(z2,Ts,linestyle='--',color='steelblue',label='fx=0.1 ($T_s$ \u2260 $T_k$)')
ax.plot(z2,Ts2,linestyle='--',color='darkred',label='fx=1000 ($T_s$ \u2260 $T_k$)')
ax.plot(z2,Ts4,linestyle='--',color='darkolivegreen',label='fx=46.4 ($T_s$ \u2260 $T_k$)')
ax.plot(z2,T_spin,linestyle='-',color='blue',label='fx=0.1')
ax.plot(z2,T_spin2,linestyle='-',color='red',label='fx=1000')
ax.plot(z2,T_spin4,linestyle='-',color='green',label='fx=46.4')
ax.set_title("Spin Temperature Comparisons at fixed minimum Halo-mass $10^{9}$ $M_{\\odot}$")
ax.set_xlabel("<--- z")    
ax.set_ylabel("$T_{spin}$ [K]--->")
ax.set_ylim(0,100) #CLOSE-UP
ax.invert_xaxis()
ax.grid(True)
ax.legend()
plt.show()

# %%
#varying fx=0.1,1000,46.4  fixed min halo-mass=10^10

fig,ax=plt.subplots(figsize=(12,8))

ax.plot(z2,Ts1,linestyle='--',color='steelblue',label='fx=0.1 ($T_s$ \u2260 $T_k$)')
ax.plot(z2,Ts3,linestyle='--',color='darkred',label='fx=1000 ($T_s$ \u2260 $T_k$)')
ax.plot(z2,Ts5,linestyle='--',color='darkolivegreen',label='fx=46.4 ($T_s$ \u2260 $T_k$)')
ax.plot(z2,T_spin1,linestyle='-',color='blue',label='fx=0.1')
ax.plot(z2,T_spin3,linestyle='-',color='red',label='fx=1000')
ax.plot(z2,T_spin5,linestyle='-',color='green',label='fx=46.4')
ax.set_title("Spin Temperature Comparisons at fixed minimum Halo-mass $10^{10}$ $M_{\\odot}$")
ax.set_xlabel("<--- z")    
ax.set_ylabel("$T_{spin}$ [K]--->")
#ax.set_ylim(0,4000)
ax.invert_xaxis()
ax.grid(True)
ax.legend()
plt.show()

# %%
"""
For varying fx=0.1,1000,46.4 at fixed halo mass 10^10:
I have observed the divergence is most again for fx1000. 
Divergence at z=around 13 , for 0.1fx
Divergence at z=around 13.5 , for 46.4fx
Divergence at z=around 13 , for 1000fx
Here,  spin temperature couples best with Kinetic Temperature for the model fx0.1
"""

# %%
#varying fx=0.1,1000,46.4  fixed min halo-mass=10^10

fig,ax=plt.subplots(figsize=(12,8))

ax.plot(z2,Ts1,linestyle='--',color='steelblue',label='fx=0.1 ($T_s$ \u2260 $T_k$)')
ax.plot(z2,Ts3,linestyle='--',color='darkred',label='fx=1000 ($T_s$ \u2260 $T_k$)')
ax.plot(z2,Ts5,linestyle='--',color='darkolivegreen',label='fx=46.4 ($T_s$ \u2260 $T_k$)')
ax.plot(z2,T_spin1,linestyle='-',color='blue',label='fx=0.1')
ax.plot(z2,T_spin3,linestyle='-',color='red',label='fx=1000')
ax.plot(z2,T_spin5,linestyle='-',color='green',label='fx=46.4')
ax.set_title("Spin Temperature Comparisons at fixed minimum Halo-mass $10^{10}$ $M_{\\odot}$")
ax.set_xlabel("<--- z")    
ax.set_ylabel("$T_{spin}$ [K]--->")
ax.set_ylim(0,200) #CLOSE-UP
ax.invert_xaxis()
ax.grid(True)
ax.legend()
plt.show()

# %%
#varying min halo-mass=10^9, 10^10, Fixed fx=0.1 

fig,ax=plt.subplots(figsize=(12,8))

ax.plot(z2,Ts,linestyle='--',color='steelblue',label='$10^{9}$ $M_{\\odot}$ ($T_s$ \u2260 $T_k$)')
ax.plot(z2,Ts1,linestyle='--',color='darkred',label='$10^{10}$ $M_{\\odot}$ ($T_s$ \u2260 $T_k$)')

ax.plot(z2,T_spin,linestyle='-',color='blue',label='$10^{9}$ $M_{\\odot}$')
ax.plot(z2,T_spin1,linestyle='-',color='red',label='$10^{10}$ $M_{\\odot}$')

ax.set_title("Spin Temperature Comparisons at fixed fx=0.1")
ax.set_xlabel("<--- z")    
ax.set_ylabel("$T_{spin}$ [K]--->")
#ax.set_ylim(0,4000)
ax.invert_xaxis()
ax.grid(True)
ax.legend()
plt.show()

# %%
#varying min halo-mass=10^9, 10^10, Fixed fx=1000 

fig,ax=plt.subplots(figsize=(12,8))

ax.plot(z2,Ts2,linestyle='--',color='steelblue',label='$10^{9}$ $M_{\\odot}$ ($T_s$ \u2260 $T_k$)')
ax.plot(z2,Ts3,linestyle='--',color='darkred',label='$10^{10}$ $M_{\\odot}$ ($T_s$ \u2260 $T_k$)')

ax.plot(z2,T_spin2,linestyle='-',color='blue',label='$10^{9}$ $M_{\\odot}$')
ax.plot(z2,T_spin3,linestyle='-',color='red',label='$10^{10}$ $M_{\\odot}$')

ax.set_title("Spin Temperature Comparisons at fixed fx=1000")
ax.set_xlabel("<--- z")    
ax.set_ylabel("$T_{spin}$ [K]--->")
#ax.set_ylim(0,4000)
ax.invert_xaxis()
ax.grid(True)
ax.legend()
plt.show()

# %%
#varying min halo-mass=10^9, 10^10, Fixed fx=1000 

fig,ax=plt.subplots(figsize=(12,8))

ax.plot(z2,Ts2,linestyle='--',color='steelblue',label='$10^{9}$ $M_{\\odot}$ ($T_s$ \u2260 $T_k$)')
ax.plot(z2,Ts3,linestyle='--',color='darkred',label='$10^{10}$ $M_{\\odot}$ ($T_s$ \u2260 $T_k$)')

ax.plot(z2,T_spin2,linestyle='-',color='blue',label='$10^{9}$ $M_{\\odot}$')
ax.plot(z2,T_spin3,linestyle='-',color='red',label='$10^{10}$ $M_{\\odot}$')

ax.set_title("Spin Temperature Comparisons at fixed fx=1000")
ax.set_xlabel("<--- z")    
ax.set_ylabel("$T_{spin}$ [K]--->")
ax.set_ylim(0,500) #CLOSE-UP
ax.invert_xaxis()
ax.grid(True)
ax.legend()
plt.show()

# %%
#varying min halo-mass=10^9, 10^10, Fixed fx=46.4 

fig,ax=plt.subplots(figsize=(12,8))

ax.plot(z2,Ts4,linestyle='--',color='steelblue',label='$10^{9}$ $M_{\\odot}$ ($T_s$ \u2260 $T_k$)')
ax.plot(z2,Ts5,linestyle='--',color='darkred',label='$10^{10}$ $M_{\\odot}$ ($T_s$ \u2260 $T_k$)')

ax.plot(z2,T_spin4,linestyle='-',color='blue',label='$10^{9}$ $M_{\\odot}$')
ax.plot(z2,T_spin5,linestyle='-',color='red',label='$10^{10}$ $M_{\\odot}$')

ax.set_title("Spin Temperature Comparisons at fixed fx=46.4")
ax.set_xlabel("<--- z")    
ax.set_ylabel("$T_{spin}$ [K]--->")
#ax.set_ylim(0,4000)
ax.invert_xaxis()
ax.grid(True)
ax.legend()
plt.show()

# %%
#varying min halo-mass=10^9, 10^10, Fixed fx=46.4 

fig,ax=plt.subplots(figsize=(12,8))

ax.plot(z2,Ts4,linestyle='--',color='steelblue',label='$10^{9}$ $M_{\\odot}$ ($T_s$ \u2260 $T_k$)')
ax.plot(z2,Ts5,linestyle='--',color='darkred',label='$10^{10}$ $M_{\\odot}$ ($T_s$ \u2260 $T_k$)')

ax.plot(z2,T_spin4,linestyle='-',color='blue',label='$10^{9}$ $M_{\\odot}$')
ax.plot(z2,T_spin5,linestyle='-',color='red',label='$10^{10}$ $M_{\\odot}$')

ax.set_title("Spin Temperature Comparisons at fixed fx=46.4")
ax.set_xlabel("<--- z")    
ax.set_ylabel("$T_{spin}$ [K]--->")
ax.set_ylim(0,500) #CLOSE-UP
ax.invert_xaxis()
ax.grid(True)
ax.legend()
plt.show()

# %%
"""
For fixed fx, and varying min halo-mass of 10^9 and 10^10,
For each X-ray heating efficiency, the divergence of Spin Temperature from the Kinetic temperature with time is more for the lower halo-mass of 10^9
"""
