# %%
#Ts>>Tcmb => (1-Tcmb/Ts)=0
#delta_Tb=(26.25/1000)*xH1*(IplusD)*(((1+z)/10)*(0.14/omegaM*h**2))**0.5*(omegaB*h**2)/0.022
#Ts NOT= Tk

#delTb=(1-0)*xH1*(1+delta)

import os
import numpy as np
import matplotlib.pyplot as plt
import glob

xH1_path=r'G:\CD_data_project'
Ts_path=r"F:\\JU INTERNSHIP\\T_spin_cubes\\"
del_path=r'G:\1+delta_files'

def read_dataH0(file):
    f=open(file,'rb')
    n=np.fromfile(f,count=3,dtype='int32')
    d=np.fromfile(f,dtype='float32')
    return d.reshape((600,600,600))
    
def read_data0(file):
    with open(file, 'rb') as f:
        d = np.fromfile(f, dtype='float32')
        return d.reshape((600,600,600))

def exTractz0(m,fx):    
    pattern = os.path.join(xH1_path, f"*_{m}*_{fx}*xhi.cbin")
    files = sorted(glob.glob(pattern))
    redshifts=[]
    for f in files:        
        #extracting z from path
        fname=os.path.basename(f)
        z_=fname.split("zeta")[0]
        z=float(z_)
        redshifts.append(z)
    return sorted(np.array(redshifts))
    
def delTb0(m,fx):
    rs=exTractz0(m,fx)
    mean_Tb=[]
       
    for z in rs:
        z_str=f"{z:.3f}"
        tsPf=os.path.join(Ts_path,f"{z_str}_{m}_{fx}_tspin.cbin")
        tsP_= glob.glob(tsPf)[0]
        
        xhiPf=os.path.join(xH1_path, f"{z_str}*_{m}*_{fx}*xhi.cbin")
        xhiP_= glob.glob(xhiPf)[0]
       
        deltaPf=os.path.join(del_path, f"{z_str}_1+delta_.bin")
        deltaP_ = glob.glob(deltaPf)[0]
        
        
        Ts=read_dataH0(tsP_).reshape((600,600,600))
        xH1=read_dataH0(xhiP_).reshape((600,600,600))
        IplusD=read_data0(deltaP_).reshape((600,600,600))

        Tcmb=2.725*(1+z)
        omegaM=0.310
        omegaB=0.049
        h=0.677
        #26.25mK is a scale factor
        #Tcmb/Ts is dimensionless as both in kelvin 
        delta_Tb=(0.027 * xH1 * (IplusD) *
            np.sqrt((1 + z) / 10 * (0.15 / (omegaM * h**2))) *
            (omegaB * h**2 / 0.023))
        
        mean_Tb.append(np.mean(delta_Tb))
    
    return mean_Tb,rs

# %%
model,solar_mass="fx0.100E+00","Mmin0.100E+10"
dTb,z=delTb0(solar_mass,model)

# %%
model,solar_mass="fx0.100E+04","Mmin0.100E+10"
dTb1,z=delTb0(solar_mass,model)

# %%
model,solar_mass="fx0.464E+02","Mmin0.100E+10"
dTb2,z=delTb0(solar_mass,model)

# %%
model,solar_mass="fx0.100E+00","Mmin0.100E+11"
dTb3,z=delTb0(solar_mass,model)

# %%
model,solar_mass="fx0.100E+04","Mmin0.100E+11"
dTb4,z=delTb0(solar_mass,model)

# %%
model,solar_mass="fx0.464E+02","Mmin0.100E+11"
dTb5,z=delTb0(solar_mass,model)

# %%
#Original including heating term
#delTb=(1-Tcmb/Ts)*xH1*(1+delta)

import os
import numpy as np
import matplotlib.pyplot as plt
import glob

xH1_path=r'G:\CD_data_project'
Ts_path=r"F:\\JU INTERNSHIP\\T_spin_cubes\\"
del_path=r'G:\1+delta_files'

def read_dataH0(file):
    f=open(file,'rb')
    n=np.fromfile(f,count=3,dtype='int32')
    d=np.fromfile(f,dtype='float32')
    return d.reshape((600,600,600))
    
def read_data0(file):
    with open(file, 'rb') as f:
        d = np.fromfile(f, dtype='float32')
        return d.reshape((600,600,600))

def exTractz0(m,fx):    
    pattern = os.path.join(xH1_path, f"*_{m}*_{fx}*xhi.cbin")
    files = sorted(glob.glob(pattern))
    redshifts=[]
    for f in files:        
        #extracting z from path
        fname=os.path.basename(f)
        z_=fname.split("zeta")[0]
        z=float(z_)
        redshifts.append(z)
    return sorted(np.array(redshifts))
    
def delTb0(m,fx):
    rs=exTractz0(m,fx)
    mean_Tb=[]
       
    for z in rs:
        z_str=f"{z:.3f}"
        tsPf=os.path.join(Ts_path,f"{z_str}_{m}_{fx}_tspin.cbin")
        tsP_= glob.glob(tsPf)[0]
        
        xhiPf=os.path.join(xH1_path, f"{z_str}*_{m}*_{fx}*xhi.cbin")
        xhiP_= glob.glob(xhiPf)[0]
       
        deltaPf=os.path.join(del_path, f"{z_str}_1+delta_.bin")
        deltaP_ = glob.glob(deltaPf)[0]
        
        
        Ts=read_dataH0(tsP_).reshape((600,600,600))
        xH1=read_dataH0(xhiP_).reshape((600,600,600))
        IplusD=read_data0(deltaP_).reshape((600,600,600))

        Tcmb=2.725*(1+z)
        omegaM=0.310
        omegaB=0.049
        h=0.677
        #26.25mK is a scale factor
        #Tcmb/Ts is dimensionless as both in kelvin 
        delta_Tb=(0.027 * xH1 * (IplusD) * (1 - Tcmb / Ts) *
            np.sqrt((1 + z) / 10 * (0.15 / (omegaM * h**2))) *
            (omegaB * h**2 / 0.023))
        
        mean_Tb.append(np.mean(delta_Tb))
    
    return mean_Tb,rs

# %%
model,solar_mass="fx0.100E+00","Mmin0.100E+10"
dTb6,z6=delTb0(solar_mass,model)

# %%
model,solar_mass="fx0.100E+04","Mmin0.100E+10"
dTb7,z7=delTb0(solar_mass,model)

# %%
model,solar_mass="fx0.464E+02","Mmin0.100E+10"
dTb8,z8=delTb0(solar_mass,model)

# %%
model,solar_mass="fx0.100E+00","Mmin0.100E+11"
dTb9,z9=delTb0(solar_mass,model)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 2
#       1 model,solar_mass="fx0.100E+00","Mmin0.100E+11"
# ----> 2 dTb9,z9=delTb0(solar_mass,model)
#
# Cell In[31], line 53, in delTb0(m, fx)
#      49 deltaP_ = glob.glob(deltaPf)[0]
#      52 Ts=read_dataH0(tsP_).reshape((600,600,600))
# ---> 53 xH1=read_dataH0(xhiP_).reshape((600,600,600))
#      54 IplusD=read_data0(deltaP_).reshape((600,600,600))
#      56 Tcmb=2.725*(1+z)
#
# Cell In[31], line 16, in read_dataH0(file)
#      14 f=open(file,'rb')
#      15 n=np.fromfile(f,count=3,dtype='int32')
# ---> 16 d=np.fromfile(f,dtype='float32')
#      17 return d.reshape((600,600,600))
#
# KeyboardInterrupt:

# %%
model,solar_mass="fx0.100E+04","Mmin0.100E+11"
dTb10,z10=delTb0(solar_mass,model)

# %%
model,solar_mass="fx0.464E+02","Mmin0.100E+11"
dTb11,z11=delTb0(solar_mass,model)

# %%
#fixed halo-mass="Mmin0.100E+10"
fig,ax=plt.subplots(figsize=(10,8))

ax.plot(z6,dTb,linestyle="-",color='pink',label='fx0.100E+00 Tcmb/Ts \u2248 0')
ax.plot(z6,dTb6,linestyle="--",color='red',label='fx0.100E+00 ')

ax.plot(z6,dTb1,linestyle="-",color='royalblue',label='fx0.100E+04 Tcmb/Ts \u2248 0')
ax.plot(z6,dTb7,linestyle="--",color='royalblue',label='fx0.100E+04 ')

ax.plot(z6,dTb2,linestyle="-",color='green',label='fx0.464E+02 Tcmb/Ts \u2248 0')
ax.plot(z6,dTb8,linestyle="--",color='green',label='fx0.464E+02')

ax.set_title(f"dTb vs Redshift for fixed halo-mass {solar_mass} $M_{{\\odot}}$")
ax.set_xlabel("Redshift (z)")
ax.set_ylabel("mean delta Tb[K]")
#ax.set_xlim(14,10) #CLOSE-UP
#ax.set_ylim(0.00,0.05) #CLOSE-UP
ax.invert_xaxis()
ax.grid(True)
ax.legend()
plt.show()

# %%
#fixed halo-mass="Mmin0.100E+10"
fig,ax=plt.subplots(figsize=(10,8))

ax.plot(z6,dTb,linestyle="-",color='red',label='fx0.100E+00 Tcmb/Ts \u2248 0')
ax.plot(z6,dTb6,linestyle="--",color='red',label='fx0.100E+00 ')

ax.plot(z6,dTb1,linestyle="-",color='royalblue',label='fx0.100E+04 Tcmb/Ts \u2248 0')
ax.plot(z6,dTb7,linestyle="--",color='royalblue',label='fx0.100E+04 ')

ax.plot(z6,dTb2,linestyle="-",color='green',label='fx0.464E+02 Tcmb/Ts \u2248 0')
ax.plot(z6,dTb8,linestyle="--",color='green',label='fx0.464E+02')

ax.set_title(f"dTb vs Redshift for fixed halo-mass {solar_mass} $M_{{\\odot}}$")
ax.set_xlabel("Redshift (z)")
ax.set_ylabel("mean delta Tb[K]")
ax.set_xlim(10,12) #CLOSE-UP
ax.set_ylim(0.00,0.05) #CLOSE-UP
ax.invert_xaxis()
ax.grid(True)
ax.legend()
plt.show()

# %%
#fixed halo-mass="Mmin0.100E+11"
fig,ax=plt.subplots(figsize=(10,8))

ax.plot(z11,dTb3,linestyle="-",color='red',label='fx0.100E+00')
ax.plot(z11,dTb9,linestyle="--",color='red',label='fx0.100E+00 Ts=Tk')

ax.plot(z11,dTb4,linestyle="-",color='royalblue',label='fx0.100E+04')
ax.plot(z11,dTb10,linestyle="--",color='royalblue',label='fx0.100E+04 Ts=Tk')

ax.plot(z11,dTb5,linestyle="-",color='green',label='fx0.464E+02')
ax.plot(z11,dTb11,linestyle="--",color='green',label='fx0.464E+02 Ts=Tk')

ax.set_title(f"dTb vs Redshift for fixed halo-mass {solar_mass} $M_{{\\odot}}$")
ax.set_xlabel("Redshift (z)")
ax.set_ylabel("mean delta Tb[K]")
ax.invert_xaxis()
ax.grid(True)
ax.legend()
plt.show()
