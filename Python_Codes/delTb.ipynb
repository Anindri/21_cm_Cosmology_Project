# %%
#delTb=(1-Tcmb/Ts)*xH1*(1+delta)

import os
import numpy as np
import matplotlib.pyplot as plt
import glob

xH1_path=r'G:\CD_data_project'
Ts_path=r'G:\T_spin'
del_path=r'G:\1+delta_files'

def read_dataH(file):
    f=open(file,'rb')
    n=np.fromfile(f,count=3,dtype='int32')
    d=np.fromfile(f,dtype='float32')
    return d
    
def read_data(file):
    with open(file, 'rb') as f:
        d = np.fromfile(f, dtype='float32')
        return d

def exTractz(m,fx):    
    pattern = os.path.join(xH1_path, f"*_{m}*_{fx}*xhi.cbin")
    files = sorted(glob.glob(pattern))
    redshifts=[]
    for f in files:        
        #extracting z from path
        fname=os.path.basename(f)
        z_=fname.split("zeta")[0]
        z=float(z_)
        redshifts.append(z)
    return sorted(np.array(redshifts))
    
def delTb(m,fx):
    rs=exTractz(m,fx)
    mean_Tb=[]
       
    for z in rs:
        z_str=f"{z:.3f}"
        tsPf=os.path.join(Ts_path,f"{z_str}_{m}_{fx}_tspin.cbin")
        tsP_= glob.glob(tsPf)[0]
        #tsP=tsP_[0]
        xhiPf=os.path.join(xH1_path, f"{z_str}*_{m}*_{fx}*xhi.cbin")
        xhiP_= glob.glob(xhiPf)[0]
        #xhiP=xhiP_[0]
        deltaPf=os.path.join(del_path, f"{z_str}_1+delta_.bin")
        deltaP_ = glob.glob(deltaPf)[0]
        #deltaP=deltaP_[0]
        
        Ts=read_dataH(tsP_)
        xH1=read_dataH(xhiP_)
        IplusD=read_data(deltaP_)

        Tcmb=2.725*(1+z)
        omegaM=0.310
        omegaB=0.049
        h=0.677
        #26.25mK is a scale factor
        #Tcmb/Ts is dimensionless as both in kelvin 
        delta_Tb=(26.25/1000)(1-Tcmb/Ts)xH1(IplusD)(((1+z)/10)*(0.14/omegaM*h**2))**0.5*(omegaB*h**2)/0.022
        
        mean_Tb.append(np.mean(delta_Tb))
        
    fig,ax=plt.subplots(figsize=(10,6))   
    ax.plot(rs,mean_Tb,marker='o', linestyle='-')
    ax.set_title(f"dTb vs Redshift for {fx} and {m}")
    ax.set_xlabel("Redshift (z)")
    ax.set_ylabel("mean delta Tb [K]")
    ax.invert_xaxis()
    ax.grid(True)
    #ax.legend()
    plt.show()
# Out:
#   Cell In[149], line 61
#     delta_Tb=(26.25/1000)(1-Tcmb/Ts)xH1(IplusD)(((1+z)/10)*(0.14/omegaM*h**2))**0.5*(omegaB*h**2)/0.022
#                                     ^
# SyntaxError: invalid syntax

# %%
#fx=0.1,mass=10^9
model,solar_mass="fx0.100E+00","Mmin0.100E+10"
delTb(solar_mass,model)

# %%
#fx=0.1,mass=10^10
model,solar_mass="fx0.100E+00","Mmin0.100E+11"
delTb(solar_mass,model)

# %%
#fx=1000,mass=10^9
model,solar_mass="fx0.100E+04","Mmin0.100E+10"
delTb(solar_mass,model)

# %%
#fx=1000,mass=10^10
model,solar_mass="fx0.100E+04","Mmin0.100E+11"
dTb3=delTb(solar_mass,model)

# %%
#fx=46.4,mass=10^9
model,solar_mass="fx0.464E+02","Mmin0.100E+10"
dTb4=delTb(solar_mass,model)

# %%
#fx=46.4,mass=10^10
model,solar_mass="fx0.464E+02","Mmin0.100E+11"
dTb5=delTb(solar_mass,model)

# %%
#delTb=(1-Tcmb/Ts)*xH1*(1+delta)

import os
import numpy as np
import matplotlib.pyplot as plt
import glob

xH1_path=r'G:\CD_data_project'
Ts_path=r'G:\T_spin'
del_path=r'G:\1+delta_files'

def read_dataH0(file):
    f=open(file,'rb')
    n=np.fromfile(f,count=3,dtype='int32')
    d=np.fromfile(f,dtype='float32')
    return d
    
def read_data0(file):
    with open(file, 'rb') as f:
        d = np.fromfile(f, dtype='float32')
        return d

def exTractz0(m,fx):    
    pattern = os.path.join(xH1_path, f"*_{m}*_{fx}*xhi.cbin")
    files = sorted(glob.glob(pattern))
    redshifts=[]
    for f in files:        
        #extracting z from path
        fname=os.path.basename(f)
        z_=fname.split("zeta")[0]
        z=float(z_)
        redshifts.append(z)
    return sorted(np.array(redshifts))
    
def delTb0(m,fx):
    rs=exTractz0(m,fx)
    mean_Tb=[]
       
    for z in rs:
        z_str=f"{z:.3f}"
        tsPf=os.path.join(Ts_path,f"{z_str}_{m}_{fx}_tspin.cbin")
        tsP_= glob.glob(tsPf)[0]
        #tsP=tsP_[0]
        xhiPf=os.path.join(xH1_path, f"{z_str}*_{m}*_{fx}*xhi.cbin")
        xhiP_= glob.glob(xhiPf)[0]
        #xhiP=xhiP_[0]
        deltaPf=os.path.join(del_path, f"{z_str}_1+delta_.bin")
        deltaP_ = glob.glob(deltaPf)[0]
        #deltaP=deltaP_[0]
        
        Ts=read_dataH0(tsP_)
        xH1=read_dataH0(xhiP_)
        IplusD=read_data0(deltaP_)

        Tcmb=2.725*(1+z)
        omegaM=0.310
        omegaB=0.049
        h=0.677
        #26.25mK is a scale factor
        #Tcmb/Ts is dimensionless as both in kelvin 
        delta_Tb=(26.25)*(1-Tcmb/Ts)*xH1*(IplusD)*(((1+z)/10)*(0.14/omegaM*h**2))**0.5*(omegaB*h**2)/0.022
        
        mean_Tb.append(np.mean(delta_Tb))
    
    return mean_Tb,rs

# %%
model,solar_mass="fx0.100E+00","Mmin0.100E+10"
dTb,z=delTb0(solar_mass,model)

# %%
print (np.mean(dTb))
# Out:
# -5.545252

# %%
model,solar_mass="fx0.100E+04","Mmin0.100E+10"
dTb1,z1=delTb0(solar_mass,model)

# %%
print (np.mean(dTb1))
# Out:
# 5.2195954

# %%
model,solar_mass="fx0.464E+02","Mmin0.100E+10"
dTb2,z2=delTb0(solar_mass,model)

# %%
print (np.mean(dTb2))
# Out:
# -3.0857377

# %%
#fixed halo-mass="Mmin0.100E+10"
fig,ax=plt.subplots(figsize=(10,8))

ax.plot(z,dTb,linestyle="-",color='red',label='fx0.100E+00')
ax.plot(z,dTb2,linestyle="-",color='green',label='fx0.464E+02')
ax.plot(z,dTb1,linestyle="-",color='blue',label='fx0.100E+04')
ax.set_title(f"dTb vs Redshift for fixed halo-mass {solar_mass} $M_{{\\odot}}$")
ax.set_xlabel("Redshift (z)")
ax.set_ylabel("mean delta Tb[mK]")
ax.invert_xaxis()
ax.grid(True)
ax.legend()
plt.show()

# %%
model,solar_mass="fx0.100E+00","Mmin0.100E+11"
dTb3,z3=delTb0(solar_mass,model)

# %%
print (np.mean(dTb3))
# Out:
# -11.430382

# %%
model,solar_mass="fx0.100E+04","Mmin0.100E+11"
dTb4,z4=delTb0(solar_mass,model)

# %%
print (np.mean(dTb4))
# Out:
# 0.17725924

# %%
model,solar_mass="fx0.464E+02","Mmin0.100E+11"
dTb5,z5=delTb0(solar_mass,model)

# %%
print (np.mean(dTb5))
# Out:
# -6.392921

# %%
#fixed halo-mass="Mmin0.100E+11"
fig,ax=plt.subplots(figsize=(10,8))

ax.plot(z,dTb3,linestyle="-",color='red',label='fx0.100E+00')
ax.plot(z,dTb5,linestyle="-",color='green',label='fx0.464E+02')
ax.plot(z,dTb4,linestyle="-",color='blue',label='fx0.100E+04')
ax.set_title(f"dTb vs Redshift for fixed halo-mass {solar_mass} $M_{{\\odot}}$")
ax.set_xlabel("Redshift (z)")
ax.set_ylabel("mean delta Tb[mK]")
ax.invert_xaxis()
ax.grid(True)
ax.legend()
plt.show()

# %%
#fixed x-ray heating efficiency="fx0.100E+00"
fig,ax=plt.subplots(figsize=(10,8))

ax.plot(z,dTb,linestyle="-",color='red',label='Mmin0.100E+10')
ax.plot(z,dTb3,linestyle="-",color='green',label='Mmin0.100E+11')

ax.set_title("dTb vs Redshift for fixed x-ray heating efficiency=fx0.100E+00")
ax.set_xlabel("Redshift (z)")
ax.set_ylabel("mean delta Tb[mK]")
ax.invert_xaxis()
ax.grid(True)
ax.legend()
plt.show()

# %%
#fixed x-ray heating efficiency="fx0.464E+02"
fig,ax=plt.subplots(figsize=(10,8))

ax.plot(z,dTb2,linestyle="-",color='red',label='Mmin0.100E+10')
ax.plot(z,dTb5,linestyle="-",color='green',label='Mmin0.100E+11')

ax.set_title("dTb vs Redshift for fixed x-ray heating efficiency=fx0.464E+02")
ax.set_xlabel("Redshift (z)")
ax.set_ylabel("mean delta Tb[mK]")
ax.invert_xaxis()
ax.grid(True)
ax.legend()
plt.show()

# %%
#fixed x-ray heating efficiency="fx0.100E+04"
fig,ax=plt.subplots(figsize=(10,8))

ax.plot(z,dTb1,linestyle="-",color='red',label='Mmin0.100E+10')
ax.plot(z,dTb4,linestyle="-",color='green',label='Mmin0.100E+11')

ax.set_title("dTb vs Redshift for fixed x-ray heating efficiency=fx0.100E+04")
ax.set_xlabel("Redshift (z)")
ax.set_ylabel("mean delta Tb[mK]")
ax.invert_xaxis()
ax.grid(True)
ax.legend()
plt.show()

# %%
#delTb=(1-Tcmb/Ts)*xH1*(1+delta)
#ASSUMING Ts=Tk 
import os
import numpy as np
import matplotlib.pyplot as plt
import glob
print("ASSUMING Ts=Tk, \n")
xH1_path=r'G:\CD_data_project'
Tk_path=r'G:\CD_data_project'
del_path=r'G:\1+delta_files'

def read_dataH(file):
    f=open(file,'rb')
    n=np.fromfile(f,count=3,dtype='int32')
    d=np.fromfile(f,dtype='float32')
    return d
    
def read_data(file):
    with open(file, 'rb') as f:
        d = np.fromfile(f, dtype='float32')
        return d

def exTractz(m,fx):    
    pattern = os.path.join(xH1_path, f"*_{m}*_{fx}*xhi.cbin")
    files = sorted(glob.glob(pattern))
    redshifts=[]
    for f in files:        
        #extracting z from path
        fname=os.path.basename(f)
        z_=fname.split("zeta")[0]
        z=float(z_)
        redshifts.append(z)
    return sorted(np.array(redshifts))
    
def delTb(m,fx):
    rs=exTractz(m,fx)
    mean_Tb=[]
       
    for z in rs:
        z_str=f"{z:.3f}"
        tsPf=os.path.join(Tk_path,f"{z_str}*_{m}*_{fx}*tk.cbin")
        tsP_= glob.glob(tsPf)[0]
        #tsP=tsP_[0]
        xhiPf=os.path.join(xH1_path, f"{z_str}*_{m}*_{fx}*xhi.cbin")
        xhiP_= glob.glob(xhiPf)[0]
        #xhiP=xhiP_[0]
        deltaPf=os.path.join(del_path, f"{z_str}_1+delta_.bin")
        deltaP_ = glob.glob(deltaPf)[0]
        #deltaP=deltaP_[0]
        
        Ts=read_dataH(tsP_)
        xH1=read_dataH(xhiP_)
        IplusD=read_data(deltaP_)

        Tcmb=2.725*(1+z)
        omegaM=0.310
        omegaB=0.049
        h=0.677
        #26.25mK is a scale factor
        #Tcmb/Ts is dimensionless as both in kelvin 
        delta_Tb=0.001*(1-Tcmb/Ts)*xH1*IplusD*26.25*(((1+z)/10 * 0.14/(omegaM*h**2))**0.5)*(omegaB*h**2)/0.022
        
        mean_Tb.append(np.mean(delta_Tb))
        
    fig,ax=plt.subplots(figsize=(10,6))   
    ax.plot(rs,mean_Tb,marker='o', linestyle='-')
    ax.set_title(f"dTb vs Redshift for {fx} and {m}")
    ax.set_xlabel("Redshift (z)")
    ax.set_ylabel("mean delta Tb")
    ax.invert_xaxis()
    ax.grid(True)
    #ax.legend()
    plt.show()
# Out:
# ASSUMING Ts=Tk,

# %%
#fx=0.1,mass=10^9
model,solar_mass="fx0.100E+00","Mmin0.100E+10"
delTb(solar_mass,model)

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import glob
print("ASSUMING Ts=Tk, \n")
xH1_path=r'G:\CD_data_project'
Tk_path=r'G:\CD_data_project'
del_path=r'G:\1+delta_files'

def read_dataH0(file):
    f=open(file,'rb')
    n=np.fromfile(f,count=3,dtype='int32')
    d=np.fromfile(f,dtype='float32')
    #print(f"{file} has data {d}")
    return d
    
def read_data0(file):
    with open(file, 'rb') as f:
        d = np.fromfile(f, dtype='float32')
        return d

def exTractz0(m,fx):    
    pattern = os.path.join(xH1_path, f"*_{m}*_{fx}*xhi.cbin")
    files = sorted(glob.glob(pattern))
    redshifts=[]
    for f in files:        
        #extracting z from path
        fname=os.path.basename(f)
        z_=fname.split("zeta")[0]
        z=float(z_)
        redshifts.append(z)
    return sorted(np.array(redshifts))
    
def delTb0(m,fx):
    rs=exTractz0(m,fx)
    #print(f'rs is {rs}')
    mean_Tb=[]
       
    for z in rs:
        #print(f'z is {z}')
        z_str=f"{z:.3f}"
        tsPf=os.path.join(Tk_path,f"{z_str}*_{m}*_{fx}*tk.cbin")
       # print(f'tsPf {tsPf}')
        tsP_= glob.glob(tsPf)[0]
        #tsP=tsP_[0]
        xhiPf=os.path.join(xH1_path, f"{z_str}*_{m}*_{fx}*xhi.cbin")
        xhiP_= glob.glob(xhiPf)[0]
        #xhiP=xhiP_[0]
        deltaPf=os.path.join(del_path, f"{z_str}_1+delta_.bin")
        deltaP_ = glob.glob(deltaPf)[0]
        #deltaP=deltaP_[0]
        
        Ts=read_dataH0(tsP_)
        #print(f' meanTs is {np.mean(Ts)} for z {z}')
        xH1=read_dataH0(xhiP_)
        IplusD=read_data0(deltaP_)

        Tcmb=2.725*(1+z)
        omegaM=0.310
        omegaB=0.049
        h=0.677
        #26.25mK is a scale factor
        #Tcmb/Ts is dimensionless as both in kelvin 
        delta_Tb=((26.25)*(1-Tcmb/Ts)*xH1*(IplusD)*(((1+z)/10)*(0.14/omegaM*h**2))**0.5*(omegaB*h**2)/0.022)/1000
        
        mean_Tb.append(np.mean(delta_Tb))
    
    return mean_Tb,rs
# Out:
# ASSUMING Ts=Tk,

# %%
model,solar_mass="fx0.100E+00","Mmin0.100E+10"
dTb6,z6=delTb0(solar_mass,model)

# %%
print (dTb6)
# Out:
# [-0.23393813, -0.24186411, -0.2484305, -0.25384188, -0.25787973, -0.26224262, -0.2629618, -0.26293725, -0.26238883, -0.26125816, -0.25964797, -0.25761932, -0.2551464, -0.25233477, -0.24919218, -0.24574418, -0.24204476, -0.238106, -0.23395072, -0.22959006, -0.22503522, -0.22029261, -0.21534893]

# %%
print (np.mean(dTb6))
# Out:
# -7.8573966

# %%
model,solar_mass="fx0.100E+04","Mmin0.100E+10"
dTb7,z7=delTb0(solar_mass,model)

# %%
print (np.mean(dTb7))
# Out:
# -0.5761142

# %%
model,solar_mass="fx0.464E+02","Mmin0.100E+10"
dTb8,z8=delTb0(solar_mass,model)

# %%
print (np.mean(dTb8))
# Out:
# -3.019911

# %%
#fixed halo-mass="Mmin0.100E+10"
fig,ax=plt.subplots(figsize=(10,8))

ax.plot(z6,dTb6,linestyle="-",color='red',label='fx0.100E+00')
ax.plot(z6,dTb8,linestyle="-",color='green',label='fx0.464E+02')
ax.plot(z6,dTb7,linestyle="-",color='blue',label='fx0.100E+04')
ax.set_title(f"dTb vs Redshift for fixed halo-mass {solar_mass} $M_{{\\odot}}$ when Ts=Tk")
ax.set_xlabel("Redshift (z)")
ax.set_ylabel("mean delta Tb[mK]")
ax.invert_xaxis()
ax.grid(True)
ax.legend()
plt.show()

# %%
model,solar_mass="fx0.100E+00","Mmin0.100E+11"
dTb9,z9=delTb0(solar_mass,model)

# %%
print (np.mean(dTb9))
# Out:
# -8.241378

# %%
model,solar_mass="fx0.100E+04","Mmin0.100E+11"
dTb10,z10=delTb0(solar_mass,model)

# %%
print (np.mean(dTb10))
# Out:
# -2.5792873

# %%
model,solar_mass="fx0.464E+02","Mmin0.100E+11"
dTb11,z11=delTb0(solar_mass,model)

# %%
print (np.mean(dTb11))
# Out:
# -5.2848682

# %%
#fixed halo-mass="Mmin0.100E+11"
fig,ax=plt.subplots(figsize=(10,8))

ax.plot(z9,dTb9,linestyle="-",color='red',label='fx0.100E+00')
ax.plot(z9,dTb11,linestyle="-",color='green',label='fx0.464E+02')
ax.plot(z9,dTb10,linestyle="-",color='blue',label='fx0.100E+04')
ax.set_title(f"dTb vs Redshift for fixed halo-mass {solar_mass} $M_{{\\odot}}$ when Ts=Tk")
ax.set_xlabel("Redshift (z)")
ax.set_ylabel("mean delta Tb[mK]")
ax.invert_xaxis()
ax.grid(True)
ax.legend()
plt.show()

# %%
#fixed x-ray heating efficiency="fx0.100E+00"
fig,ax=plt.subplots(figsize=(10,8))

ax.plot(z9,dTb6,linestyle="-",color='red',label='Mmin0.100E+10')
ax.plot(z9,dTb9,linestyle="-",color='green',label='Mmin0.100E+11')

ax.set_title("dTb vs Redshift for fixed x-ray heating efficiency=fx0.464E+02")
ax.set_xlabel("Redshift (z)")
ax.set_ylabel("mean delta Tb[mK]")
ax.invert_xaxis()
ax.grid(True)
ax.legend()
plt.show()

# %%
#fixed x-ray heating efficiency="fx0.100E+04"
fig,ax=plt.subplots(figsize=(10,8))

ax.plot(z9,dTb7,linestyle="-",color='red',label='Mmin0.100E+10')
ax.plot(z9,dTb10,linestyle="-",color='green',label='Mmin0.100E+11')

ax.set_title("dTb vs Redshift for fixed x-ray heating efficiency=fx0.100E+04")
ax.set_xlabel("Redshift (z)")
ax.set_ylabel("mean delta Tb[mK]")
ax.invert_xaxis()
ax.grid(True)
ax.legend()
plt.show()

# %%
#fixed x-ray heating efficiency="fx0.464E+02"
fig,ax=plt.subplots(figsize=(10,8))

ax.plot(z9,dTb8,linestyle="-",color='red',label='Mmin0.100E+10')
ax.plot(z9,dTb11,linestyle="-",color='green',label='Mmin0.100E+11')

ax.set_title("dTb vs Redshift for fixed x-ray heating efficiency=fx0.464E+02")
ax.set_xlabel("Redshift (z)")
ax.set_ylabel("mean delta Tb[mK]")
ax.invert_xaxis()
ax.grid(True)
ax.legend()
plt.show()

# %%
fig,ax=plt.subplots(figsize=(10,8))

ax.plot(z6,dTb,linestyle="-",color='orange',label='[$T_s$ \u2260 $T_k$] \n fx0.100E+00')
ax.plot(z6,dTb6,linestyle="-",color='cornflowerblue',label='[$T_s$ = $T_k$] \n fx0.100E+00 ')

ax.plot(z6,dTb1,linestyle="-",color='gold',label='[$T_s$ \u2260 $T_k$] \n fx0.100E+04 ')
ax.plot(z6,dTb7,linestyle="-",color='blue',label='[$T_s$ = $T_k$] \n fx0.100E+04 ')

ax.plot(z6,dTb2,linestyle="-",color='brown',label='[$T_s$ \u2260 $T_k$] \n fx0.464E+02')
ax.plot(z6,dTb8,linestyle="-",color='navy',label='[$T_s$ = $T_k$] \n fx0.464E+02 ')

ax.set_title(f"dTb Comparison for halo-mass $10^{9}$ $M_{{\\odot}}$ ")
ax.set_xlabel("Redshift (z)")
ax.set_ylabel("mean delta Tb[mK]")
ax.invert_xaxis()
ax.grid(True)
ax.legend(title='X-ray Heating Efficiencies')
plt.show()

# %%
#CLOSE-UP
fig,ax=plt.subplots(figsize=(10,8))

ax.plot(z6,dTb,linestyle="-",color='orange',label='[$T_s$ \u2260 $T_k$] \n fx0.100E+00 ')
ax.plot(z6,dTb6,linestyle="-",color='cornflowerblue',label='[$T_s$ = $T_k$] \n fx0.100E+00 ')

ax.plot(z6,dTb1,linestyle="-",color='gold',label='[$T_s$ \u2260 $T_k$] \n fx0.100E+04 ')
ax.plot(z6,dTb7,linestyle="-",color='blue',label='[$T_s$ = $T_k$] \n fx0.100E+04')

ax.plot(z6,dTb2,linestyle="-",color='brown',label='[$T_s$ \u2260 $T_k$] \n fx0.464E+02 ')
ax.plot(z6,dTb8,linestyle="-",color='navy',label='[$T_s$ = $T_k$] \n fx0.464E+02')

ax.set_title(f"dTb Comparison for halo-mass $10^{9}$ $M_{{\\odot}}$ ")
ax.set_xlabel("Redshift (z)")
ax.set_ylabel("mean delta Tb[mK]")
ax.set_ylim(-150,2)
ax.invert_xaxis()
ax.grid(True)
ax.legend(title='X-ray Heating Efficiencies')
plt.show()

# %%
fig,ax=plt.subplots(figsize=(10,8))

ax.plot(z6,dTb3,linestyle="-",color='orange',label='[$T_s$ \u2260 $T_k$] \n fx0.100E+00 ')
ax.plot(z6,dTb9,linestyle="-",color='cornflowerblue',label='[$T_s$ = $T_k$] \n fx0.100E+00 ')

ax.plot(z6,dTb4,linestyle="-",color='gold',label='[$T_s$ \u2260 $T_k$] \n fx0.100E+04 ')
ax.plot(z6,dTb10,linestyle="-",color='blue',label='[$T_s$ = $T_k$] \n fx0.100E+04')

ax.plot(z6,dTb5,linestyle="-",color='brown',label='[$T_s$ \u2260 $T_k$] \n fx0.464E+02')
ax.plot(z6,dTb11,linestyle="-",color='navy',label='[$T_s$ = $T_k$] \n fx0.464E+02')

ax.set_title(f"dTb Comparison for halo-mass $10^{{10}}$ $M_{{\\odot}}$")
ax.set_xlabel("Redshift (z)")
ax.set_ylabel("mean delta Tb[mK]")
ax.invert_xaxis()
ax.grid(True)
ax.legend(title='X-ray Heating Efficiencies')
plt.show()
